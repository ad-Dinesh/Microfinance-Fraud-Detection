# %% [markdown]
# # Microfinance Fraud Detection using Machine Learning
#
# ## Data Understanding
#
# ### Objective
#
# The goal of this notebook is to understand the structure, quality, and characteristics of the Microfinance Fraud Detection dataset before performing exploratory analysis and model development.
#
# ### Tasks
#
# - Load the dataset
# - Understand dataset dimensions
# - Explore feature names
# - Check data types
# - Detect missing values
# - Detect duplicate records
# - Generate statistical summary
# - Identify categorical and numerical features
# - Analyze target variable distribution

# %%
import numpy as np
import pandas as pd

pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", 100)

# %%
df = pd.read_csv("C:\\Users\\Dinesh\\OneDrive\\Desktop\\Microfinance-Fraud-Detection\\data\\raw\\microfinance_fraud_detection_dataset.csv")

print("dataset Loaded successfully")
# Out:
# dataset Loaded successfully

# %%
df.head()
# Out:
#   transaction_id customer_id branch_id    loan_id  customer_age  gender  \
# 0      TXN000001   CUST01825     BR049  LOAN04822            43    Male
# 1      TXN000002   CUST00410     BR174  LOAN05235            36    Male
# 2      TXN000003   CUST04507     BR163  LOAN07508            45  Female
# 3      TXN000004   CUST04013     BR158  LOAN12869            56  Female
# 4      TXN000005   CUST03658     BR021  LOAN06457            35    Male
#
#   marital_status education_level            occupation  annual_income  \
# 0       Divorced         Diploma               Retired       45591.89
# 1        Married         Primary                Farmer       75316.77
# 2        Married             PhD  Small Business Owner       53905.76
# 3         Single       Secondary         Self-Employed       34222.08
# 4       Divorced       Secondary     Salaried Employee       89250.89
#
#    monthly_expenses  credit_score  years_with_institution  \
# ...

# %%
print(f"Rows    : {df.shape[0]}")
print(f"Columns : {df.shape[1]}")
# Out:
# Rows    : 50000
# Columns : 95

# %%
df.columns.tolist()
# Out:
# ['transaction_id',
#  'customer_id',
#  'branch_id',
#  'loan_id',
#  'customer_age',
#  'gender',
#  'marital_status',
#  'education_level',
#  'occupation',
#  'annual_income',
#  'monthly_expenses',
#  'credit_score',
#  'years_with_institution',
#  'previous_loan_count',
#  'dependents',
#  'home_ownership',
#  'mobile_registered',
#  'region',
#  'state',
#  'distance_to_branch_km',
#  'branch_transaction_volume',
#  'branch_fraud_rate_history',
#  'loan_purpose',
#  'requested_amount',
#  'approved_amount',
#  'disbursed_amount',
#  'loan_term_months',
#  'interest_rate',
#  'loan_to_income_ratio',
#  'collateral_provided',
#  'guarantors_count',
#  'group_lending',
#  'application_channel',
#  'processing_time_days',
#  'device_type',
#  'browser_type',
#  'network_type',
#  'scheduled_installment',
#  'actual_installment_paid',
#  'payment_frequency',
#  'days_overdue',
#  'missed_payments',
#  'total_payments_made',
#  'payment_method',
#  'remaining_balance',
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 95 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   transaction_id                50000 non-null  str
#  1   customer_id                   50000 non-null  str
#  2   branch_id                     50000 non-null  str
#  3   loan_id                       50000 non-null  str
#  4   customer_age                  50000 non-null  int64
#  5   gender                        50000 non-null  str
#  6   marital_status                50000 non-null  str
#  7   education_level               50000 non-null  str
#  8   occupation                    50000 non-null  str
#  9   annual_income                 50000 non-null  float64
#  10  monthly_expenses              50000 non-null  float64
#  11  credit_score                  50000 non-null  int64
#  12  years_with_institution        50000 non-null  float64
# ...

# %%
missing = df.isnull().sum()

missing = missing[missing > 0]

# %%
duplicates = df.duplicated().sum()

print("Duplicate Rows : ", duplicates)
# Out:
# Duplicate Rows :  0

# %%
df.describe().T
# Out:
#                                 count           mean            std  \
# customer_age                  50000.0      37.762780      11.452916
# annual_income                 50000.0   49268.755009   42573.657077
# monthly_expenses              50000.0   33249.962626   30432.378850
# credit_score                  50000.0     643.511100      86.180634
# years_with_institution        50000.0       3.014100       2.992990
# previous_loan_count           50000.0       1.998540       1.405026
# dependents                    50000.0       2.259260       1.608047
# distance_to_branch_km         50000.0       4.993392       4.996572
# branch_transaction_volume     50000.0    5047.483080    2855.500823
# branch_fraud_rate_history     50000.0       0.032508       0.015932
# requested_amount              50000.0   15229.835364   17640.411654
# approved_amount               50000.0   11402.724779   13587.547740
# disbursed_amount              50000.0   10263.760162   12280.948666
# ...

# %%
categorical_columns = df.select_dtypes(include=["object"]).columns.tolist()

print("Categorical Features")

categorical_columns
# Out:
# Categorical Features
# C:\Users\Dinesh\AppData\Local\Temp\ipykernel_14144\3934334861.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   categorical_columns = df.select_dtypes(include=["object"]).columns.tolist()
# ['transaction_id',
#  'customer_id',
#  'branch_id',
#  'loan_id',
#  'gender',
#  'marital_status',
#  'education_level',
#  'occupation',
#  'home_ownership',
#  'region',
#  'state',
#  'loan_purpose',
#  'application_channel',
#  'device_type',
#  'browser_type',
#  'network_type',
#  'payment_frequency',
#  'payment_method',
#  'sanctions_screening',
# ...

# %%
boolean_columns = df.select_dtypes(include=["bool"]).columns.tolist()
print("Boolean Features")
boolean_columns
# Out:
# Boolean Features
# ['mobile_registered',
#  'collateral_provided',
#  'group_lending',
#  'high_value_transaction_flag',
#  'biometric_verification',
#  'blacklist_match',
#  'duplicate_application',
#  'identity_verification_failed',
#  'pep_flag',
#  'income_discrepancy']

# %%
df["is_fraud"].value_counts()
# Out:
# is_fraud
# 0    48487
# 1     1513
# Name: count, dtype: int64

# %%
(df["is_fraud"].value_counts(normalize=True) * 100).round(2)
# Out:
# is_fraud
# 0    96.97
# 1     3.03
# Name: proportion, dtype: float64

# %%
df.nunique().sort_values()
# Out:
# group_lending                       2
# collateral_provided                 2
# mobile_registered                   2
# biometric_verification              2
# blacklist_match                     2
# high_value_transaction_flag         2
# identity_verification_failed        2
# duplicate_application               2
# income_discrepancy                  2
# pep_flag                            2
# is_fraud                            2
# sanctions_screening                 3
# gender                              3
# marital_status                      4
# payment_frequency                   4
# region                              4
# guarantors_count                    4
# reference_check_result              4
# home_ownership                      4
# sim_card_changes                    4
# loan_status                         5
# application_channel                 5
# payment_method                      5
# loan_term_months                    6
# device_type                         6
# ...

# %% [markdown]
# # Initial Observations
#
# ### Dataset Summary
#
# - Dataset contains customer, loan, transaction, digital behavior, and compliance information.
# - Target variable is **is_fraud**.
# - Fraud cases are expected to represent a small percentage of the dataset.
# - Dataset contains numerical, categorical, and boolean features.
# - No preprocessing has been applied yet.
# - Data understanding is completed successfully.
